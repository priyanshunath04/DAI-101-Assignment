# %%
## Importing all important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Load and display the first 5 rows of the dataset
df = pd.read_csv("StudentPerformanceFactors.csv")
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
## Renaming a column
df.rename(columns={"Hours_Studied":"Hours_Studied_Per_Week"}, inplace=True)
df.columns
# Out:
# Index(['Hours_Studied_Per_Week', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type',
#        'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender',
#        'Exam_Score'],
#       dtype='object')

# %%
df.shape
# Out:
# (6607, 20)

# %%
## Summary statistics for numerical columns in the DataFrame
df.describe()
# Out:
#        Hours_Studied_Per_Week   Attendance  Sleep_Hours  Previous_Scores  \
# count             6607.000000  6607.000000   6607.00000      6607.000000
# mean                19.975329    79.977448      7.02906        75.070531
# std                  5.990594    11.547475      1.46812        14.399784
# min                  1.000000    60.000000      4.00000        50.000000
# 25%                 16.000000    70.000000      6.00000        63.000000
# 50%                 20.000000    80.000000      7.00000        75.000000
# 75%                 24.000000    90.000000      8.00000        88.000000
# max                 44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# ...

# %%
## Concise summary of the DataFrame, including data types and non-null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied_Per_Week      6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
## Total number of missing (NaN) values in each column
df.isna().sum()
# Out:
# Hours_Studied_Per_Week         0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
## Dropping rows containing NAN values as the rows containing missing values are very less as compared the dataset
df.dropna(inplace= True)

# %%
df.isnull().sum()
# Out:
# Hours_Studied_Per_Week        0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
## Checking duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Hours_Studied_Per_Week, Attendance, Parental_Involvement, Access_to_Resources, Extracurricular_Activities, Sleep_Hours, Previous_Scores, Motivation_Level, Internet_Access, Tutoring_Sessions, Family_Income, Teacher_Quality, School_Type, Peer_Influence, Physical_Activity, Learning_Disabilities, Parental_Education_Level, Distance_from_Home, Gender, Exam_Score]
# Index: []

# %%
## Separating categorical and numerical columns
cat_col = []    ## list containing categorical columns  names
num_col = []    ## list containing numerical columns  names
for column in df.columns:
    if df[column].dtype == 'O':
        cat_col.append(column)
    else:
        num_col.append(column)

# %% [markdown]
# <h1 style="color:#10ded7"> UNIVARIATE ANALYSIS

# %%
df.head()
# Out:
#    Hours_Studied_Per_Week  Attendance Parental_Involvement  \
# 0                      23          84                  Low
# 1                      19          64                  Low
# 2                      24          98               Medium
# 3                      29          89                  Low
# 4                      19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  Tutoring_Sessions  \
# 0               73              Low             Yes                  0
# 1               59              Low             Yes                  2
# ...

# %% [markdown]
# # CATEGORICAL DATA

# %%
for column in cat_col:
    df[column].value_counts().plot(kind= "bar")
    plt.show()

# %% [markdown]
# # NUMERICAL DATA

# %%
num_col
# Out:
# ['Hours_Studied_Per_Week',
#  'Attendance',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Tutoring_Sessions',
#  'Physical_Activity',
#  'Exam_Score']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
## sns.kdeplot(df["Hours_Studied_Per_Week"], color="#9045ad", shade=True)

# %% [markdown]
# <h3> DATA CLEANING

# %%
sns.boxplot(df["Hours_Studied_Per_Week"])
# Out:
# <Axes: ylabel='Hours_Studied_Per_Week'>

# %%
## Removing outliers from Hours_Studied_Per_Week column
Q1 = df["Hours_Studied_Per_Week"].quantile(0.25)
Q3 = df["Hours_Studied_Per_Week"].quantile(0.75)
IQR = Q3-Q1
df = df[(df["Hours_Studied_Per_Week"]>(Q1 - 1.5*IQR)) & (df["Hours_Studied_Per_Week"]<(Q3 + 1.5*IQR))]
sns.boxplot(df["Hours_Studied_Per_Week"])
# Out:
# <Axes: ylabel='Hours_Studied_Per_Week'>

# %%
sns.histplot(df["Attendance"], color="#9045ad", bins=20, kde=True)
# Out:
# <Axes: xlabel='Attendance', ylabel='Count'>

# %%
sns.boxplot(df["Sleep_Hours"])
# Out:
# <Axes: ylabel='Sleep_Hours'>

# %%
# df["Sleep_Hours"].value_counts().plot(kind="bar")
# plt.xticks(rotation = 0)

# %%
sns.boxplot(df["Previous_Scores"])
# Out:
# <Axes: ylabel='Previous_Scores'>

# %%
sns.boxplot(df["Tutoring_Sessions"])
len(df[df["Tutoring_Sessions"] == 4])
# Out:
# 294

# %%
## Removing outliers from Tutoring_Sessions column
Q1 = df["Tutoring_Sessions"].quantile(0.25)
Q3 = df["Tutoring_Sessions"].quantile(0.75)
IQR = Q3-Q1
df = df[(df["Tutoring_Sessions"]>(Q1 - 1.5*IQR)) & (df["Tutoring_Sessions"]<(Q3 + 1.5*IQR))]
sns.boxplot(df["Tutoring_Sessions"])
# Out:
# <Axes: ylabel='Tutoring_Sessions'>

# %%
sns.boxplot(df["Physical_Activity"])
# Out:
# <Axes: ylabel='Physical_Activity'>

# %% [markdown]
# -----

# %% [markdown]
# <h2> ANALYSIS

# %%
num_col
# Out:
# ['Hours_Studied_Per_Week',
#  'Attendance',
#  'Sleep_Hours',
#  'Previous_Scores',
#  'Tutoring_Sessions',
#  'Physical_Activity',
#  'Exam_Score']

# %%
sns.kdeplot(df["Hours_Studied_Per_Week"], shade=True)
# Out:
# <Axes: xlabel='Hours_Studied_Per_Week', ylabel='Density'>

# %%
sns.histplot(df["Attendance"])
# Out:
# <Axes: xlabel='Attendance', ylabel='Count'>

# %% [markdown]
# There's three kind of students that's why there are three peaks in the histogram. Majority of students have attendance around 80 out of 100

# %%
df["Sleep_Hours"].value_counts().sort_index().plot(kind="bar")
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, '4'),
#   Text(1, 0, '5'),
#   Text(2, 0, '6'),
#   Text(3, 0, '7'),
#   Text(4, 0, '8'),
#   Text(5, 0, '9'),
#   Text(6, 0, '10')])

# %% [markdown]
# Majority of students get 7 hours of sleep. Students who get very less and more amounut of sleep are lesser in number.

# %%
sns.histplot(df["Previous_Scores"], kde=True)
# Out:
# <Axes: xlabel='Previous_Scores', ylabel='Count'>

# %%
sns.histplot(df["Exam_Score"], kde=True)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Count'>

# %% [markdown]
# Marks Distribution follows normal distribution without skewness but as compared to previous cores, students didn't score high marks in exam.

# %%
df["Tutoring_Sessions"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Tutoring_Sessions'>

# %%
df["Physical_Activity"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Physical_Activity'>

# %%
sns.kdeplot(df["Exam_Score"], shade=True)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Density'>

# %% [markdown]
# -----

# %% [markdown]
# <h1 style="color:#60fa07"> MULTIVARIATE ANALYSIS

# %%
df.corr(numeric_only=True)
# Out:
#                         Hours_Studied_Per_Week  Attendance  Sleep_Hours  \
# Hours_Studied_Per_Week                1.000000   -0.010863     0.009410
# Attendance                           -0.010863    1.000000    -0.023972
# Sleep_Hours                           0.009410   -0.023972     1.000000
# Previous_Scores                       0.020156   -0.017838    -0.021613
# Tutoring_Sessions                    -0.005094    0.009368    -0.002354
# Physical_Activity                     0.004097   -0.027721    -0.000814
# Exam_Score                            0.433860    0.585139    -0.016929
#
#                         Previous_Scores  Tutoring_Sessions  Physical_Activity  \
# Hours_Studied_Per_Week         0.020156          -0.005094           0.004097
# Attendance                    -0.017838           0.009368          -0.027721
# Sleep_Hours                   -0.021613          -0.002354          -0.000814
# Previous_Scores                1.000000          -0.023576          -0.004409
# ...

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# <h1 style="color:#fca10d"> ENCODING Of Categorical Data

# %%
for column in cat_col:
    print(column,":",df[column].unique())
# Out:
# Parental_Involvement : ['Low' 'Medium' 'High']
# Access_to_Resources : ['High' 'Medium' 'Low']
# Extracurricular_Activities : ['No' 'Yes']
# Motivation_Level : ['Low' 'Medium' 'High']
# Internet_Access : ['Yes' 'No']
# Family_Income : ['Low' 'Medium' 'High']
# Teacher_Quality : ['Medium' 'High' 'Low']
# School_Type : ['Public' 'Private']
# Peer_Influence : ['Positive' 'Negative' 'Neutral']
# Learning_Disabilities : ['No' 'Yes']
# Parental_Education_Level : ['High School' 'College' 'Postgraduate']
# Distance_from_Home : ['Near' 'Moderate' 'Far']
# Gender : ['Male' 'Female']

# %%
## columns having 2 unique values - label encoding
## columns having 3 unique values - label or ordinal encoding
lab_enc_col = []
ord_enc_col = []
for column in cat_col:
    if df[column].nunique() == 2:
        lab_enc_col.append(column)
    else:
        ord_enc_col.append(column)

# %%
print(lab_enc_col)
print(ord_enc_col)
# Out:
# ['Extracurricular_Activities', 'Internet_Access', 'School_Type', 'Learning_Disabilities', 'Gender']
# ['Parental_Involvement', 'Access_to_Resources', 'Motivation_Level', 'Family_Income', 'Teacher_Quality', 'Peer_Influence', 'Parental_Education_Level', 'Distance_from_Home']

# %%
df.head()
# Out:
#    Hours_Studied_Per_Week  Attendance Parental_Involvement  \
# 0                      23          84                  Low
# 1                      19          64                  Low
# 2                      24          98               Medium
# 3                      29          89                  Low
# 4                      19          92               Medium
#
#   Access_to_Resources Extracurricular_Activities  Sleep_Hours  \
# 0                High                         No            7
# 1              Medium                         No            8
# 2              Medium                        Yes            7
# 3              Medium                        Yes            8
# 4              Medium                        Yes            6
#
#    Previous_Scores Motivation_Level Internet_Access  Tutoring_Sessions  \
# 0               73              Low             Yes                  0
# 1               59              Low             Yes                  2
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_encoder = OrdinalEncoder(categories=[["Low", "Medium", "High"]])
for column in ord_enc_col:
    if ((column!= "Peer_Influence") & (column!="Distance_from_Home") & (column!="Parental_Education_Level")):
        df[column] = ord_encoder.fit_transform(df[[column]])

ord_encoder = OrdinalEncoder(categories=[['High School', 'College', 'Postgraduate']])
df["Parental_Education_Level"] = ord_encoder.fit_transform(df[["Parental_Education_Level"]])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in lab_enc_col:
    df[column] = le.fit_transform(df[column])
df["Peer_Influence"].replace({"Positive":2, "Neutral":1, "Negative":0}, inplace=True)
df["Distance_from_Home"].replace({"Far":2, "Moderate":1, "Near":0}, inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied_Per_Week  Attendance  Parental_Involvement  \
# 0                      23          84                   0.0
# 1                      19          64                   0.0
# 2                      24          98                   1.0
# 3                      29          89                   0.0
# 4                      19          92                   1.0
#
#    Access_to_Resources  Extracurricular_Activities  Sleep_Hours  \
# 0                  2.0                           0            7
# 1                  1.0                           0            8
# 2                  1.0                           1            7
# 3                  1.0                           1            8
# 4                  1.0                           1            6
#
#    Previous_Scores  Motivation_Level  Internet_Access  Tutoring_Sessions  \
# 0               73               0.0                1                  0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is some correlation between Exam Scores and Attendance & Study Hours per week

# %%
sns.scatterplot(x="Attendance", y="Exam_Score", data=df)
# Out:
# <Axes: xlabel='Attendance', ylabel='Exam_Score'>

# %%
sns.scatterplot(x="Hours_Studied_Per_Week", y="Exam_Score", data=df)
# Out:
# <Axes: xlabel='Hours_Studied_Per_Week', ylabel='Exam_Score'>

# %%
sns.boxplot(data=df, x="Access_to_Resources", y="Exam_Score")
# Out:
# <Axes: xlabel='Access_to_Resources', ylabel='Exam_Score'>

# %%
sns.boxplot(data=df, x="Motivation_Level", y="Exam_Score")
# Out:
# <Axes: xlabel='Motivation_Level', ylabel='Exam_Score'>

# %%
sns.boxplot(data=df, x="Gender", y="Exam_Score")
# Out:
# <Axes: xlabel='Gender', ylabel='Exam_Score'>

# %%
sns.boxplot(data=df, x="Teacher_Quality", y="Exam_Score")
# Out:
# <Axes: xlabel='Teacher_Quality', ylabel='Exam_Score'>

# %%
sns.boxplot(data=df, x="Tutoring_Sessions", y="Exam_Score")
# Out:
# <Axes: xlabel='Tutoring_Sessions', ylabel='Exam_Score'>
